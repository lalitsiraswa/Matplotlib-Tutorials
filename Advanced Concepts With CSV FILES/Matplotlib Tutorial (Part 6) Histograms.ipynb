# %%
from  matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use('fivethirtyeight')

ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]

plt.hist(ages, bins = 5, edgecolor = "black")

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.tight_layout()

# %%
plt.style.use("fivethirtyeight")

ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]
bins = [10, 20, 30, 40, 50, 60]

plt.hist(ages, bins = bins, edgecolor = "black")

plt.title("Ages of Respodents")
plt.xlabel("Ages")
plt.ylabel("Totlal Respondents")

plt.tight_layout()

# %%
plt.style.use("fivethirtyeight")

ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]
bins = [20, 30, 40, 50, 60]

plt.hist(ages, bins = bins, edgecolor = "black")

plt.title("Ages of Respodents")
plt.xlabel("Ages")
plt.ylabel("Total Respondents")

plt.tight_layout()

# %%
plt.style.use("fivethirtyeight")

data = pd.read_csv("files/Histograms.csv")
ids = data["Responder_id"]
ages = data["Age"]

bins = [10, 20, 30, 40, 50, 60, 70, 80, 90]

plt.hist(ages, bins = bins, edgecolor = "black")

plt.title("Ages of Respondents")
plt.xlabel("Ages")
plt.ylabel("Total Respondents")
# Out:
# Text(0, 0.5, 'Total Respondents')

# %%
plt.style.use("fivethirtyeight")

data = pd.read_csv("files/Histograms.csv")
ids = data["Responder_id"]
ages = data["Age"]

bins = [10, 20, 30, 40, 50, 60, 70, 80, 90]

plt.hist(ages, bins = bins, edgecolor = "black", log = True)

plt.title("Ages of Respondents")
plt.xlabel("Ages")
plt.ylabel("Total Respondents")

plt.tight_layout()

# %%
plt.style.use("fivethirtyeight")

data = pd.read_csv("files/Histograms.csv")
ids = data["Responder_id"]
ages = data["Age"]

median_age = 29

bins = [10, 20, 30, 40, 50, 60, 70, 80, 90]

plt.hist(ages, bins = bins, edgecolor = "black", log = True)

plt.axvline(median_age, color = "green")

plt.title("Ages of Respondents")
plt.xlabel("Ages")
plt.ylabel("Total Respondents")

plt.tight_layout()

# %%
plt.style.use('fivethirtyeight')

ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]
bins = [10, 20, 40, 50, 60]

plt.hist(ages, bins = bins, edgecolor = "black")

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.tight_layout()
