# %%
import numpy as np
import pandas as pd
import plotly as pl
import cufflinks as cf
import plotly.offline as po
# %matplotlib inline

# %%
po.init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1 = pd.DataFrame(np.random.rand(100, 5), columns = ["a", "b", "c", "d", "e"])
df1.head(2)
# Out:
#           a         b         c         d         e
# 0  0.696612  0.076004  0.336704  0.480756  0.241683
# 1  0.609872  0.039466  0.540269  0.282793  0.310879

# %%
df2 = pd.DataFrame({'x' : ['a', 'b', 'c', 'd', 'e'], 'y' : [1, 2, 3, 4, 5], 'z' : [6, 7, 8, 4, 3]})
df2.head(2)
# Out:
#    x  y  z
# 0  a  1  6
# 1  b  2  7

# %%
df1.iplot(kind = "scatter")
# Out:
# <div>
#
#
#             <div id="ee5b5c59-d89a-45a5-b36c-58a618bebab5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ee5b5c59-d89a-45a5-b36c-58a618bebab5")) {
#                     Plotly.newPlot(
#                         'ee5b5c59-d89a-45a5-b36c-58a618bebab5',
# ...

# %%
df2.iplot()
# Out:
# <div>
#
#
#             <div id="2bee839b-ba11-47e3-9419-10c104b1ba6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2bee839b-ba11-47e3-9419-10c104b1ba6f")) {
#                     Plotly.newPlot(
#                         '2bee839b-ba11-47e3-9419-10c104b1ba6f',
# ...

# %%
df2
# Out:
#    x  y  z
# 0  a  1  6
# 1  b  2  7
# 2  c  3  8
# 3  d  4  4
# 4  e  5  3

# %%
df1.tail(2)
# Out:
#            a         b         c         d         e
# 98  0.748391  0.411832  0.290351  0.681925  0.347783
# 99  0.201050  0.375628  0.223213  0.081538  0.949032

# %%
df1.iplot(x = "a", y = "b")
# Out:
# <div>
#
#
#             <div id="393e306f-0026-4a33-856d-9510f7f3b1e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("393e306f-0026-4a33-856d-9510f7f3b1e4")) {
#                     Plotly.newPlot(
#                         '393e306f-0026-4a33-856d-9510f7f3b1e4',
# ...

# %%
df1.iplot(x = "a", y = "b", mode = "markers")
# Out:
# <div>
#
#
#             <div id="276b4027-6e31-46c0-8fe1-24edac8781f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("276b4027-6e31-46c0-8fe1-24edac8781f5")) {
#                     Plotly.newPlot(
#                         '276b4027-6e31-46c0-8fe1-24edac8781f5',
# ...

# %%
df2.iplot(x = "y", y = "z", mode = "markers")
# Out:
# <div>
#
#
#             <div id="54e1ecef-186c-434d-8a39-36e554e34392" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("54e1ecef-186c-434d-8a39-36e554e34392")) {
#                     Plotly.newPlot(
#                         '54e1ecef-186c-434d-8a39-36e554e34392',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 12, "symbol": "circle"}, "mode": "markers", "name": "z", "text": "", "type": "scatter", "x": [1, 2, 3, 4, 5], "y": [6, 7, 8, 4, 3]}],
# ...

# %%
df2.iplot(x = "x", y = "z", mode = "markers")
# Out:
# <div>
#
#
#             <div id="e733d33a-bb53-41f3-9c8d-34f9d36a21c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e733d33a-bb53-41f3-9c8d-34f9d36a21c0")) {
#                     Plotly.newPlot(
#                         'e733d33a-bb53-41f3-9c8d-34f9d36a21c0',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 12, "symbol": "circle"}, "mode": "markers", "name": "z", "text": "", "type": "scatter", "x": ["a", "b", "c", "d", "e"], "y": [6, 7, 8, 4, 3]}],
# ...

# %%
df2
# Out:
#    x  y  z
# 0  a  1  6
# 1  b  2  7
# 2  c  3  8
# 3  d  4  4
# 4  e  5  3

# %%
df2.iplot(x = "x", y = "z", mode = "markers", size = 25)
# Out:
# <div>
#
#
#             <div id="b04f739c-c2c9-4081-be59-ff8e6dcc0160" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b04f739c-c2c9-4081-be59-ff8e6dcc0160")) {
#                     Plotly.newPlot(
#                         'b04f739c-c2c9-4081-be59-ff8e6dcc0160',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 25, "symbol": "circle"}, "mode": "markers", "name": "z", "text": "", "type": "scatter", "x": ["a", "b", "c", "d", "e"], "y": [6, 7, 8, 4, 3]}],
# ...

# %%
df2.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="7009c78c-c6ac-412a-8465-7eeed717640b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7009c78c-c6ac-412a-8465-7eeed717640b")) {
#                     Plotly.newPlot(
#                         '7009c78c-c6ac-412a-8465-7eeed717640b',
# ...

# %%
df1.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="ee5e29fe-2dfb-4fea-853f-e1dcd5fee041" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ee5e29fe-2dfb-4fea-853f-e1dcd5fee041")) {
#                     Plotly.newPlot(
#                         'ee5e29fe-2dfb-4fea-853f-e1dcd5fee041',
# ...

# %%
df = pd.DataFrame({"x" : [1, 3, 5, 7, 9, 3, 7], "y" : [3, 5, 4, 1, 7, 8, 4], "z" : [2, 4, 7, 5, 1, 0, 4]})
df
# Out:
#    x  y  z
# 0  1  3  2
# 1  3  5  4
# 2  5  4  7
# 3  7  1  5
# 4  9  7  1
# 5  3  8  0
# 6  7  4  4

# %%
df.iplot(kind = "scatter")
# Out:
# <div>
#
#
#             <div id="9cf3c1c7-4a31-4f9b-bd86-1cd59d3bcb97" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9cf3c1c7-4a31-4f9b-bd86-1cd59d3bcb97")) {
#                     Plotly.newPlot(
#                         '9cf3c1c7-4a31-4f9b-bd86-1cd59d3bcb97',
# ...

# %%
df.iplot(kind = "scatter", x = "y", y = "z")
# Out:
# <div>
#
#
#             <div id="14930c8a-df86-4b16-8f5b-8cbddd8d953c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("14930c8a-df86-4b16-8f5b-8cbddd8d953c")) {
#                     Plotly.newPlot(
#                         '14930c8a-df86-4b16-8f5b-8cbddd8d953c',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "z", "text": "", "type": "scatter", "x": [3, 5, 4, 1, 7, 8, 4], "y": [2, 4, 7, 5, 1, 0, 4]}],
# ...

# %%
df.iplot(x = "x", y = "z", kind = "scatter")
# Out:
# <div>
#
#
#             <div id="332290be-148f-46f5-b351-86dbbf0add06" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("332290be-148f-46f5-b351-86dbbf0add06")) {
#                     Plotly.newPlot(
#                         '332290be-148f-46f5-b351-86dbbf0add06',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "z", "text": "", "type": "scatter", "x": [1, 3, 5, 7, 9, 3, 7], "y": [2, 4, 7, 5, 1, 0, 4]}],
# ...

# %%
df.iplot(x = "x", y = "y", kind = "scatter", mode = "markers", color = "blacK", size = 20)
# Out:
# <div>
#
#
#             <div id="e99a6752-b296-4830-8247-011a0dfc78da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e99a6752-b296-4830-8247-011a0dfc78da")) {
#                     Plotly.newPlot(
#                         'e99a6752-b296-4830-8247-011a0dfc78da',
#                         [{"line": {"color": "rgba(0, 0, 0, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 20, "symbol": "circle"}, "mode": "markers", "name": "y", "text": "", "type": "scatter", "x": [1, 3, 5, 7, 9, 3, 7], "y": [3, 5, 4, 1, 7, 8, 4]}],
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="35539146-0a5b-4d8c-b5db-b5a478c02c7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("35539146-0a5b-4d8c-b5db-b5a478c02c7a")) {
#                     Plotly.newPlot(
#                         '35539146-0a5b-4d8c-b5db-b5a478c02c7a',
# ...

# %%
df.iplot(x = "x", y = "y", kind = "scatter", mode = "markers", size = 15, symbol = "x", colorscale = "paired")
# Out:
# <div>
#
#
#             <div id="472522d4-af5e-4099-9826-9794571873d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("472522d4-af5e-4099-9826-9794571873d4")) {
#                     Plotly.newPlot(
#                         '472522d4-af5e-4099-9826-9794571873d4',
#                         [{"line": {"color": "rgba(166, 206, 227, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 15, "symbol": "x"}, "mode": "markers", "name": "y", "text": "", "type": "scatter", "x": [1, 3, 5, 7, 9, 3, 7], "y": [3, 5, 4, 1, 7, 8, 4]}],
# ...
