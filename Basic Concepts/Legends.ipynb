# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(0, 10, 20)
y = x * x
z = x + y

# %%
plt.plot(x, y, label = "Simple Graph")
plt.legend()

# %%
plt.scatter(x, y, label = "Scatter Graph")
plt.legend()

# %%
plt.hist(x, y, label = "Historical Graph")
plt.legend()

# %%
plt.bar(y, x, label = "Bar Graph")
plt.legend()

# %%
plt.fill(y, x, label = "Fill Graph")
plt.legend()

# %%
plt.plot(y, x, label = "Demo Graph")
plt.legend(loc = 1)

# %%
plt.plot(y, x, label = "Demo Graph")
plt.legend(loc = 10)

# %%
plt.plot(y, x, label = "Demo Graph")
plt.legend(loc = 9)

# %%
plt.plot(y, x, label = "Demo Graph")
plt.legend(loc = 3)

# %%
plt.plot(y, x, label = "Demo Graph")
plt.legend(loc = 4)

# %%
plt.plot(y, x, label = "Demo Graph")
plt.legend(loc = 6)

# %%
plt.plot(y, x, label = "Demo Graph")
plt.legend(loc = 7)
